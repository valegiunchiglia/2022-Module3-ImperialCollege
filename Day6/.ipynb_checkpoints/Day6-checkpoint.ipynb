# %% [markdown]
#                                             Workshop 6: Valentina Giunchiglia, Annalaura Lerede and Dragos Gruia

# %% [markdown]
# # Introduction to Machine Learning

# %%
import pandas as pd

# %%
df = pd.read_csv("Day6_data.csv")
df.head()
# Out:
#    Unnamed: 0   RID   AGE PTGENDER  PTEDUCAT         PTETHCAT PTRACCAT  \
# 0           3  1758  72.0   Female        14  Not Hisp/Latino    White
# 1          31   228  81.8   Female        18  Not Hisp/Latino    White
# 2          37  2622  82.8   Female        19  Not Hisp/Latino    White
# 3          39  4642  72.4     Male        20  Not Hisp/Latino    White
# 4          51  3363  82.0     Male        16  Not Hisp/Latino    White
#
#     PTMARRY  CDRSB  ADAS11  ...   FAQ        ICV        DX  mPACCdigit  \
# 0  Divorced    1.1    5.77  ...   5.0  1649732.0  Dementia   -1.898237
# 1  Divorced    0.4    1.46  ...   2.0  1596566.0  Dementia    4.650690
# 2   Widowed    0.9    9.64  ...   2.0  1639781.0  Dementia   -8.578941
# 3   Married    4.2   10.09  ...  10.0  1546803.0       MCI   -7.949650
# 4   Married    0.7   12.26  ...   0.0  1658122.0       MCI   -5.328186
#
#    mPACCtrailsB  Fusiform  Hippocampus  MidTemp  Ventricles  has_converted
# ...
